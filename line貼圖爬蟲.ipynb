# %%
import requests as req
import os, json
from bs4 import BeautifulSoup as bs

# %%
from fake_useragent import UserAgent
ua = UserAgent(use_external_data=True)

# %%
ua.random
# Out:
# 'Mozilla/5.0 (Windows NT 6.3; rv:36.0) Gecko/20100101 Firefox/36.0'

# %%
folderPath = "line_stickers"
if not os.path.exists(folderPath):
    os.makedirs(folderPath)

# %%
python -m pip freeze

# %%
# !pip freeze

# %%
#放貼圖資訊用
listlineStickers = []

my_headers = {
    "user-agent":ua.random
}

# 官方 LINE 貼圖的網址
url = 'https://store.line.me/stickershop/product/19716012/zh-Hant'

# 將自訂標頭加入 GET 請求中
res = req.get(url, headers = my_headers)

# 建立 soup 物件
soup = bs(res.text, 'lxml')

soup
# Out:
# <!--
#   ~ Copyright (c) 2018 LINE Corporation. All rights reserved.
#   ~ LINE Corporation PROPRIETARY/CONFIDENTIAL. Use is subject to license terms.
#   --><!DOCTYPE html>
# <html data-lang="zh-Hant" lang="zh-Hant">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, user-scalable=yes, initial-scale=1" name="viewport"/>
# <title>貓貓蟲咖波-黑白素描奇怪表情篇 – LINE貼圖 | LINE STORE</title>
# <meta content="黑白素描風格的奇怪表情咖波貼圖" name="description"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="website" property="og:type"/>
# <meta content="貓貓蟲咖波-黑白素描奇怪表情篇 – LINE貼圖 | LINE STORE" property="og:title"/>
# <meta content="https://store.line.me/stickershop/product/19716012/zh-Hant" property="og:url"/>
# <meta content="黑白素描風格的奇怪表情咖波貼圖" property="og:description"/>
# <meta content="LINE STORE" property="og:site_name"/>
# <meta content="zh_TW" property="og:locale"/>
# <meta content="zh_HK" property="og:locale:alternative"/><meta content="ko_KR" property="og:locale:alternative"/><meta content="en_PI" property="og:locale:alternative"/><meta content="th_TH" property="og:locale:alternative"/><meta content="en_US" property="og:locale:alternative"/><meta content="zh_TW" property="og:locale:alternative"/><meta content="zh_MO" property="og:locale:alternative"/><meta content="en_GB" property="og:locale:alternative"/><meta content="ja_KS" property="og:locale:alternative"/><meta content="in_ID" property="og:locale:alternative"/><meta content="ja_JP" property="og:locale:alternative"/><meta content="en_IN" property="og:locale:alternative"/><meta content="pt_BR" property="og:locale:alternative"/><meta content="en_UD" property="og:locale:alternative"/>
# <meta content="https://stickershop.line-scdn.net/stickershop/v1/product/19716012/LINEStorePC/main.png" property="og:image"/>
# <meta content="https://stickershop.line-scdn.net/stickershop/v1/product/19716012/LINEStorePC/main.png" name="twitter:image"/>
# <meta content="貓貓蟲咖波-黑白素描奇怪表情篇 – LINE貼圖 | LINE STORE" name="twitter:title"/>
# <meta content="黑白素描風格的奇怪表情咖波貼圖" name="twitter:description"/>
# <meta content="summary" name="twitter:card"/>
# <link href="https://store.line.me/stickershop/product/19716012/zh-Hant" rel="canonical"/>
# <link href="https://store.line.me/stickershop/product/19716012/ja" hreflang="ja" rel="alternate"/><link href="https://store.line.me/stickershop/product/19716012/en" hreflang="en" rel="alternate"/><link href="https://store.line.me/stickershop/product/19716012/zh-Hant" hreflang="zh-Hant" rel="alternate"/><link href="https://store.line.me/stickershop/product/19716012/ko" hreflang="ko" rel="alternate"/><link href="https://store.line.me/stickershop/product/19716012/th" hreflang="th" rel="alternate"/><link href="https://store.line.me/stickershop/product/19716012/id" hreflang="id" rel="alternate"/><link href="https://store.line.me/stickershop/product/19716012/pt-BR" hreflang="pt-BR" rel="alternate"/><link href="https://store.line.me/stickershop/product/19716012" hreflang="x-default" rel="alternate"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="LINE STORE" name="application-name"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="LINE STORE" name="apple-mobile-web-app-title"/>
# <link href="https://scdn.line-apps.com/n/line_store_sp/img/apple_touch_icon_228_20160805.png" rel="apple-touch-icon" sizes="228x228"/>
# <link href="https://scdn.line-apps.com/n/line_store_sp/img/apple_touch_icon_144_20160805.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://scdn.line-apps.com/n/line_store_sp/img/apple_touch_icon_192_20160805.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://scdn.line-apps.com/n/line_store_sp/img/favicon_20160805.ico" rel="shortcut icon" type="image/x-icon"/>
# <script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type": "Product",
#     "sku": "19716012",
#     "url": "https://store.line.me/stickershop/product/19716012/zh-Hant",
#
#     "name": "\u8C93\u8C93\u87F2\u5496\u6CE2-\u9ED1\u767D\u7D20\u63CF\u5947\u602A\u8868\u60C5\u7BC7",
#     "description": "\u9ED1\u767D\u7D20\u63CF\u98A8\u683C\u7684\u5947\u602A\u8868\u60C5\u5496\u6CE2\u8CBC\u5716",
#     "image": "https://stickershop.line-scdn.net/stickershop/v1/product/19716012/LINEStorePC/main.png",
#     "offers": {
#       "@type": "Offer",
#       "price": "30",
#       "priceCurrency": "TWD",
#       "url": "https://store.line.me/stickershop/product/19716012/zh-Hant"
#     }
#   }
# </script>
# <link crossorigin="anonymous" defer="" href="https://static.line-scdn.net/laicon/edge/8.0/laicon.min.css" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://static.line-scdn.net/line_store/18793c626e9/pc/css/line_store_pc.css" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://static.line-scdn.net/line_store/edge/store/main.428d13dd.min.css" rel="stylesheet"/>
# </head>
# <body class="ExOsMac">
# <div class="LyWrap">
# <header class="LyHead">
# <h1 class="MdGHD01Logo">
# <a href="/home/zh-Hant">LINE STORE</a>
# </h1>
# <div class="MdGHD02Search" data-widget="SearchBox">
# <form action="/search/zh-Hant" method="GET">
# <span class="MdIcoSearch01 FnSearchIcon" data-test="search-icon"></span>
# <span></span>
# <input class="FnSearchInput" data-test="search-field" name="q" placeholder="搜尋" type="text" value=""/>
# </form>
# </div>
# <ul class="MdGHD03Util">
# <li class="mdGHD03Li">
# <a href="/notice/list/zh-Hant">
# <span class="MdIcoNew04"></span><span>最新資訊</span>
# </a>
# <span class="mdGHD03Line">|</span>
# </li>
# <li class="mdGHD03Li" data-test="wishlist-btn">
# <div class="MdLYR01Box mdLYR01WLTop" data-feature-type="WISHLIST_TUTORIAL_PC_HOME" data-widget="TutorialModalWindow" data-widget-plugin="DisableTouchScroll" style="display: none">
# <div class="MdLYR02Body mdLYR02WLTop">
# <a class="mdLYR02Close FnModalWindowClose" href="javascript:;"><span class="MdBtnClose01">關閉</span></a>
# <div class="MdLYR10Notice mdLYR10WL">
# <div class="mdLYR10Txt">
# <h2 class="mdLYR10Ttl" data-test="wishlist-tutorial-title">快來用看看願望清單吧！</h2>
# <p class="mdLYR10Desc01" data-test="wishlist-tutorial-description">只要在貼圖或主題的頁面中，點選<em>♡按鍵</em>，就能不斷將自己喜歡的項目加到願望清單中喔！
# 點選首頁的<em>♡按鍵</em>，即可確認願望清單。</p>
# <!--/mdLYR10Txt--></div>
# <!--/MdLYR10Notice--></div>
# </div>
# <!--/MdLYR01Box--></div>
# <a href="/wishlist/zh-Hant"><span class="MdIcoWishlist01"></span><span>願望清單</span></a>
# <span class="mdGHD03Line">|</span>
# </li>
# <li class="mdGHD03Li" data-test="login-btn"><a href="/login/zh-Hant?url=%2Fstickershop%2Fproduct%2F19716012%2Fzh-Hant" rel="nofollow">登入</a></li>
# </ul>
# </header>
# <div class="LyContents MdCF">
# <div class="LySub">
# <nav class="MdSB06Nav" role="navigation">
# <ul>
# <li class="title flexVerticalCenter">
# <i class="lar la-smile"></i>
# <span>貼圖</span>
# </li>
# <li>
# <a class="flexVerticalCenter" href="/stickers-premium/landing/zh-Hant">
# <span data-event-action="click_premium_sidemenu_PC" data-event-category="sticker" data-event-label="Premium">LINE貼圖超值方案</span>
# <img alt="" height="14" src="https://static.line-scdn.net/line_store/1814c5eeaa1/pc/img/common/img_charge_premium.svg" style="margin-left: 10px;"/>
# </a>
# </li>
# <li data-test="stickershop-side-menu-item">
# <a data-event-action="click_menu_sticker_pc" data-event-category="common" href="/stickershop/home/general/zh-Hant">官方貼圖</a>
# </li>
# <li class="ExSelected" data-test="creators-stickershop-side-menu-item">
# <a data-event-action="click_menu_cm-sticker_pc" data-event-category="common" href="/stickershop/home/user/zh-Hant">個人原創貼圖</a>
# </li>
# </ul>
# <hr/>
# <ul>
# <li class="title flexVerticalCenter">
# <i class="labr la-line-friends"></i>
# <span>表情貼</span>
# </li>
# <li data-test="emojishop-side-menu-item">
# <a data-event-action="click_menu_emoji_pc" data-event-category="common" href="/emojishop/home/general/zh-Hant">官方表情貼</a>
# </li>
# <li data-test="creators-emojishop-side-menu-item">
# <a data-event-action="click_menu_cs-emoji_pc" data-event-category="common" href="/emojishop/home/creators/zh-Hant">個人原創表情貼</a>
# </li>
# </ul>
# <hr/>
# <ul>
# <li class="title flexVerticalCenter">
# <i class="lar la-brush"></i> <span>主題</span>
# </li>
# <li data-test="themeshop-side-menu-item">
# <a data-event-action="click_menu_theme_pc" data-event-category="common" href="/themeshop/home/zh-Hant">官方主題</a>
# </li>
# <li data-test="creators-themeshop-side-menu-item">
# <a data-event-action="click_menu_cs-theme_pc" data-event-category="common" href="/themeshop/home/creators/zh-Hant">個人原創主題</a>
# </li>
# </ul>
# <hr/>
# <ul data-test="side-menu">
# <li class="title flexVerticalCenter">
# <i class="labr la-line-messenger-alt"></i>
# <span>LINE服務</span>
# </li>
# <li data-test="mangashop-side-menu-item">
# <a class="flexVerticalCenter" href="/naver/webtoon/zh-Hant">
# <i class="labr la-line-webtoon"></i>
# <span data-event-action="click_menu_webtoon_pc" data-event-category="common">WEBTOON</span>
# </a>
# </li>
# <li data-test="gameshop-side-menu-item">
# <a class="flexVerticalCenter" href="/game/zh-Hant">
# <i class="labr la-line-faceplay"></i>
# <span data-event-action="click_menu_game_pc" data-event-category="common">LINE GAME</span>
# </a>
# </li>
# <li data-test="playshop-side-menu-item">
# <a class="flexVerticalCenter" href="/family/play/zh-Hant">
# <i class="labr la-line-play"></i>
# <span data-event-action="click_menu_play_pc" data-event-category="common">LINE PLAY</span>
# </a>
# </li>
# </ul>
# <hr/>
# <ul>
# <li>
# <a class="flexVerticalCenter" href="https://help.line.me/webstore/web?lang=zh-Hant">
# <i class="lar la-question-circle"></i>
# <span>常見問題</span>
# </a>
# </li>
# </ul>
# </nav>
# </div>
# <div class="LyMain" role="main">
# <section class="MdBox03">
# <div class="mdBox03Inner01">
# <!-- Movie Button Over-->
# <div class="MdCMN38EndTop mdCMN38Sticker">
# <div class="mdCMN38Img" data-preview='{ "type" : "static", "id" : "19716012", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/product/19716012/LINEStorePC/main.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-widget="MainSticker" data-widget-id="MainSticker" ref="mainImage">
# <img alt="貓貓蟲咖波-黑白素描奇怪表情篇" class="FnImage" height="230" src="https://stickershop.line-scdn.net/stickershop/v1/product/19716012/LINEStorePC/main.png" width="230"/>
# <div class="MdIcoPremium_b">Premium</div>
# <div class="FnPreviewWrapper"></div>
# </div>
# <ul class="mdCMN38Item01">
# <div class="mdCMN38Item0lHead">
# <p class="mdCMN38Item01Ttl" data-test="sticker-name-title">貓貓蟲咖波-黑白素描奇怪表情篇</p>
# </div>
# <a class="mdCMN38Item01Author" data-test="sticker-author" href="/stickershop/author/24287/zh-Hant">亞拉</a>
# <p class="mdCMN38Item01Txt">黑白素描風格的奇怪表情咖波貼圖</p>
# <div class="mdCMN38Item01Info" data-test="sticker-price-info">
# <p class="mdCMN38Item01Price" data-test="sticker-price">NT$30</p>
# <p class="mdCMN38Item01Wish" onclick="moveToAddWish()">
# <label class="MdIco01Wish">
# <input data-widget="WishCheckbox" name="" type="checkbox" value=""/>
# <span class="mdIco01WishTxt" data-test="wish-btn">リストに追加する</span>
# </label>
# </p>
# <script>/*<![CDATA[*/
#                 function moveToAddWish(){
#                   document.location = "\/login\/zh-Hant?url=\/stickershop\/product\/19716012\/wish\/zh-Hant?_csrf%3D1328bd32-cba1-43e7-a30e-3595301c60c7";
#                 }
#                 /*]]>*/</script>
# </div>
# <ul class="mdCMN38Item01Ul" data-custom-sticker="CustomSticker" data-widget="PurchaseButtons" data-widget-id="PurchaseButtons">
# <li>
# <button class="MdBtn01P02" data-event-label="sticker_creators" data-href="/login/?url=%2Fstickershop%2Fproduct%2F19716012%2Fzh-Hant" data-test="present-btn" data-trigger-target="ModalWindowPresent" data-widget="LinkButton">贈送禮物</button>
# </li>
# <li>
# <button class="MdBtn01P01" data-event-label="sticker_creators" data-href="/stickershop/payment?packageId=19716012&amp;confirmedPrice=NT%2430" data-reload="true" data-test="purchase-btn" data-widget="PopUpButton" data-win-height="800" data-win-width="815" rel="nofollow">購買</button>
# </li>
# </ul>
# <div class="mdCMN38Item01Sub">
# <button class="MdBtn03 mdBtn03P01" data-event-action="click_sticker_premium_trial_PC" data-event-category="sticker" data-event-label="sticker_creators" data-href="/stickers-premium/redirectToSubscriptionLpIfNeeded/zh-Hant?packageId=19716012" data-widget="LinkButton" type="button">免費試用（貼圖用到飽）</button>
# </div>
# </ul>
# </div>
# <div class="MdHLine01"></div>
# <div class="MdCMN09DetailView mdCMN09Sticker">
# <div class="mdCMN09Preview">
# <div class="mdCMN09PreviewTxt" data-test="preview-text">
# <div data-update-user-collapse-disclaimer-api="/api/userdisclaimer/update/zh-Hant" data-widget="CreatorDisclaimerAccordion" style="margin-bottom: 10px;">
# <div class="accordion-button" data-collapse-target="#disclaimer" data-test="disclaimer-accordion-button">
# <span>關於提供給創作者的資訊</span>
# </div>
# <p data-test="disclaimer" id="disclaimer">
# <br/>
#       本公司收集相關購買數據以提供販售報告給內容創作者。<br/><br/>該販售報告包含購買日期及購買者所註冊的國家或地區，並未包含任何可識別用戶的資訊。
#
#         <br/><br/>
# </p>
# </div>
#
#
#       點擊貼圖即可預覽。
#     </div>
# </div>
# <div class="mdCMN09ImgList" data-is-big="false" data-widget="StickerPreview" data-widget-id="StickerPreview">
# <div class="MdLoader FnLoading" style="opacity: 0">
# <div class="mdLoaderInner mdLoaderDetail">
# <div class="mdLoadSpinner"></div>
# </div>
# </div>
# <div class="MdLoader FnReloadBtn" style="opacity: 0">
# <div class="mdLoaderInner">
# <p class="mdLoadReLoad" data-event-label="sticker_creators">重試</p>
# </div>
# </div>
# <div class="mdCMN09ImgListWarp">
# <ul class="mdCMN09Ul FnStickerList">
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815846", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815846/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815846/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815846/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815846/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815847", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815847/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815847/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815847/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815847/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815848", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815848/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815848/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815848/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815848/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815849", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815849/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815849/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815849/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815849/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815850", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815850/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815850/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815850/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815850/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815851", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815851/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815851/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815851/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815851/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815852", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815852/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815852/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815852/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815852/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815853", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815853/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815853/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815853/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815853/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815854", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815854/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815854/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815854/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815854/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815855", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815855/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815855/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815855/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815855/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815856", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815856/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815856/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815856/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815856/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815857", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815857/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815857/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815857/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815857/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815858", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815858/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815858/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815858/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815858/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815859", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815859/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815859/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815859/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815859/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815860", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815860/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815860/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815860/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815860/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815861", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815861/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815861/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815861/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815861/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815862", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815862/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815862/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815862/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815862/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815863", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815863/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815863/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815863/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815863/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815864", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815864/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815864/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815864/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815864/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815865", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815865/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815865/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815865/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815865/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815866", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815866/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815866/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815866/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815866/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815867", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815867/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815867/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815867/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815867/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815868", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815868/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815868/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815868/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815868/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815869", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815869/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815869/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815869/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815869/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815870", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815870/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815870/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815870/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815870/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815871", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815871/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815871/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815871/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815871/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815872", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815872/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815872/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815872/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815872/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815873", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815873/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815873/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815873/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815873/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815874", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815874/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815874/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815874/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815874/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815875", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815875/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815875/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815875/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815875/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815876", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815876/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815876/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815876/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815876/android/sticker.png);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem" data-preview='{ "type" : "static", "id" : "505815877", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815877/android/sticker.png", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/505815877/android/sticker.png", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815877/android/sticker.png);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/505815877/android/sticker.png);"></span>
# </div>
# </li>
# </ul>
# <div class="MdOverlay01 FnStickerPreviewOverlay MdNonDisp" style="pointer-events: none;"></div>
# </div>
# <div class="FnPreviewWrapper MdNonDisp">
# <div class="MdOverlay FnOverlay"></div>
# <div class="MdLYR11Sticker FnPopupCanvasWrapper">
# <div class="mdLYR11BigImg FnImgWrapper MdNonDisp"></div>
# </div>
# </div>
# </div>
# <p class="mdCMN09Copy">© Yara</p>
# <p class="mdCMN09Txt">
# <a data-event-name="openModalWindow" data-event-target="EnvironmentCaution" data-widget="EventTrigger" href="javascript:;">注意事項</a>
# <a data-reload="true" data-test="report-btn" data-widget="PopUpButton" data-win-height="760" data-win-width="692" href="/report/stickershop/19716012/zh-Hant">檢舉</a>
# </p>
# <div class="MdCMN22Share">
# <ul class="mdCMN22ShareUl">
# <li class="mdCMN22ShareLi">
# <a data-share-text="貓貓蟲咖波-黑白素描奇怪表情篇 – LINE貼圖 | LINE STORE" data-share-url="https://store.line.me/stickershop/product/19716012/zh-Hant" data-test="line-btn" data-type="line_timeline" data-widget="ShareButton" href="javascript:;" title="LINE">
# <span class="mdCMN22ShareLINE">LINE Share</span>
# </a>
# </li>
# <li class="mdCMN22ShareLi">
# <a data-share-text="貓貓蟲咖波-黑白素描奇怪表情篇 – LINE貼圖 | LINE STORE" data-share-url="https://store.line.me/stickershop/product/19716012/zh-Hant" data-test="twitter-btn" data-type="tw" data-widget="ShareButton" href="javascript:;" title="Twitter">
# <span class="mdCMN22ShareTW">Twitter Share</span>
# </a>
# </li>
# <li class="mdCMN22ShareLi">
# <a data-share-text="貓貓蟲咖波-黑白素描奇怪表情篇 – LINE貼圖 | LINE STORE" data-share-url="https://store.line.me/stickershop/product/19716012/zh-Hant" data-test="facebook-btn" data-type="fb" data-widget="ShareButton" href="javascript:;" title="Facebook">
# <span class="mdCMN22ShareFB">Facebook Share</span>
# </a>
# </li>
# </ul>
# <!--/MdCMN22Share-->
# </div>
# </div>
# </div>
# <div class="mdBox03Inner02">
# <div class="MdHead01">
# <h2 class="MdTtl02" data-test="other-sticker-title">亞拉的其他作品</h2>
# </div>
# <div class="MdCMN01List">
# <ul class="mdCMN01Ul" data-test="other-sticker-list">
# <li class="mdCMN01Li">
# <a data-event-action="click_other_product" data-event-category="sticker" data-event-label="author" href="/stickershop/product/7007511/zh-Hant?from=sticker" title="貓貓蟲咖波:貓蟲大百科">
# <div class="MdCMN07Item mdCMN07Sticker">
# <div class="mdCMN07Img" data-test="other-sticker-img">
# <img alt="貓貓蟲咖波:貓蟲大百科" height="60" src="https://stickershop.line-scdn.net/stickershop/v1/product/7007511/LINEStorePC/main.png" width="60"/>
# </div>
# <div class="mdCMN07Txt">
# <span class="MdIco01Premium">Premium</span>
# <h3 class="mdCMN07Ttl" data-test="other-author-name">貓貓蟲咖波:貓蟲大百科</h3>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN01Li">
# <a data-event-action="click_other_product" data-event-category="sticker" data-event-label="author" href="/stickershop/product/19135247/zh-Hant?from=sticker" title="貓貓蟲咖波與兔兔-愛的狙擊">
# <div class="MdCMN07Item mdCMN07Sticker">
# <div class="mdCMN07Img" data-test="other-sticker-img">
# <img alt="貓貓蟲咖波與兔兔-愛的狙擊" height="60" src="https://stickershop.line-scdn.net/stickershop/v1/product/19135247/LINEStorePC/main.png" width="60"/>
# <span class="MdIcoPlay_s" data-test="animation-sticker-icon">Animation only icon</span>
# </div>
# <div class="mdCMN07Txt">
# <span class="MdIco01Premium">Premium</span>
# <h3 class="mdCMN07Ttl" data-test="other-author-name">貓貓蟲咖波與兔兔-愛的狙擊</h3>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN01Li">
# <a data-event-action="click_other_product" data-event-category="sticker" data-event-label="author" href="/stickershop/product/21910148/zh-Hant?from=sticker" title="貓貓蟲咖波與兔兔-大心動">
# <div class="MdCMN07Item mdCMN07Sticker">
# <div class="mdCMN07Img" data-test="other-sticker-img">
# <img alt="貓貓蟲咖波與兔兔-大心動" height="60" src="https://stickershop.line-scdn.net/stickershop/v1/product/21910148/LINEStorePC/main.png" width="60"/>
# </div>
# <div class="mdCMN07Txt">
# <h3 class="mdCMN07Ttl" data-test="other-author-name">貓貓蟲咖波與兔兔-大心動</h3>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN01Li">
# <a data-event-action="click_other_product" data-event-category="sticker" data-event-label="author" href="/stickershop/product/1669361/zh-Hant?from=sticker" title="貓貓蟲咖波與兔兔-扭扭扭">
# <div class="MdCMN07Item mdCMN07Sticker">
# <div class="mdCMN07Img" data-test="other-sticker-img">
# <img alt="貓貓蟲咖波與兔兔-扭扭扭" height="60" src="https://stickershop.line-scdn.net/stickershop/v1/product/1669361/LINEStorePC/main.png" width="60"/>
# <span class="MdIcoPlay_s" data-test="animation-sticker-icon">Animation only icon</span>
# </div>
# <div class="mdCMN07Txt">
# <span class="MdIco01Premium">Premium</span>
# <h3 class="mdCMN07Ttl" data-test="other-author-name">貓貓蟲咖波與兔兔-扭扭扭</h3>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN01Li">
# <a data-event-action="click_other_product" data-event-category="sticker" data-event-label="author" href="/stickershop/product/10217926/zh-Hant?from=sticker" title="貓貓蟲咖波-招財咖波過鼠年">
# <div class="MdCMN07Item mdCMN07Sticker">
# <div class="mdCMN07Img" data-test="other-sticker-img">
# <img alt="貓貓蟲咖波-招財咖波過鼠年" height="60" src="https://stickershop.line-scdn.net/stickershop/v1/product/10217926/LINEStorePC/main.png" width="60"/>
# </div>
# <div class="mdCMN07Txt">
# <h3 class="mdCMN07Ttl" data-test="other-author-name">貓貓蟲咖波-招財咖波過鼠年</h3>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN01Li">
# <a data-event-action="click_other_product" data-event-category="sticker" data-event-label="author" href="/stickershop/product/7920494/zh-Hant?from=sticker" title="貓貓蟲咖波-上班蟲逐漸崩壞">
# <div class="MdCMN07Item mdCMN07Sticker">
# <div class="mdCMN07Img" data-test="other-sticker-img">
# <img alt="貓貓蟲咖波-上班蟲逐漸崩壞" height="60" src="https://stickershop.line-scdn.net/stickershop/v1/product/7920494/LINEStorePC/main.png" width="60"/>
# </div>
# <div class="mdCMN07Txt">
# <span class="MdIco01Premium">Premium</span>
# <h3 class="mdCMN07Ttl" data-test="other-author-name">貓貓蟲咖波-上班蟲逐漸崩壞</h3>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN01Li">
# <a data-event-action="click_other_product" data-event-category="sticker" data-event-label="author" href="/stickershop/product/1434902/zh-Hant?from=sticker" title="可靠的狗狗">
# <div class="MdCMN07Item mdCMN07Sticker">
# <div class="mdCMN07Img" data-test="other-sticker-img">
# <img alt="可靠的狗狗" height="60" src="https://stickershop.line-scdn.net/stickershop/v1/product/1434902/LINEStorePC/main.png" width="60"/>
# </div>
# <div class="mdCMN07Txt">
# <span class="MdIco01Premium">Premium</span>
# <h3 class="mdCMN07Ttl" data-test="other-author-name">可靠的狗狗</h3>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN01Li">
# <a data-event-action="click_other_product" data-event-category="sticker" data-event-label="author" href="/stickershop/product/17228844/zh-Hant?from=sticker" title="貓貓蟲咖波-職場大爆走">
# <div class="MdCMN07Item mdCMN07Sticker">
# <div class="mdCMN07Img" data-test="other-sticker-img">
# <img alt="貓貓蟲咖波-職場大爆走" height="60" src="https://stickershop.line-scdn.net/stickershop/v1/product/17228844/LINEStorePC/main.png" width="60"/>
# <span class="MdIcoPlay_s" data-test="animation-sticker-icon">Animation only icon</span>
# </div>
# <div class="mdCMN07Txt">
# <span class="MdIco01Premium">Premium</span>
# <h3 class="mdCMN07Ttl" data-test="other-author-name">貓貓蟲咖波-職場大爆走</h3>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN01Li">
# <a data-event-action="click_other_product" data-event-category="sticker" data-event-label="author" href="/stickershop/product/20931451/zh-Hant?from=sticker" title="貓貓蟲咖波-怪怪諧音梗">
# <div class="MdCMN07Item mdCMN07Sticker">
# <div class="mdCMN07Img" data-test="other-sticker-img">
# <img alt="貓貓蟲咖波-怪怪諧音梗" height="60" src="https://stickershop.line-scdn.net/stickershop/v1/product/20931451/LINEStorePC/main.png" width="60"/>
# </div>
# <div class="mdCMN07Txt">
# <h3 class="mdCMN07Ttl" data-test="other-author-name">貓貓蟲咖波-怪怪諧音梗</h3>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN01Li">
# <a data-event-action="click_other_product" data-event-category="sticker" data-event-label="author" href="/stickershop/product/4180117/zh-Hant?from=sticker" title="貓貓蟲咖波與兔兔 - 啾咪">
# <div class="MdCMN07Item mdCMN07Sticker">
# <div class="mdCMN07Img" data-test="other-sticker-img">
# <img alt="貓貓蟲咖波與兔兔 - 啾咪" height="60" src="https://stickershop.line-scdn.net/stickershop/v1/product/4180117/LINEStorePC/main.png" width="60"/>
# <span class="MdIcoPlay_s" data-test="animation-sticker-icon">Animation only icon</span>
# </div>
# <div class="mdCMN07Txt">
# <span class="MdIco01Premium">Premium</span>
# ...
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN02Li">
# <a class="FnRelatedStickerLink" data-index="39" href="/stickershop/product/18428342/zh-Hant?from=sticker" title="冠緯與他的快樂夥伴 2">
# <div class="MdCMN05Item mdCMN05Sticker">
# <img alt="" class="MdIcoPremium_s" src="https://static.line-scdn.net/line_store/1814c5eeaa1/pc/img/common/img_charge_premium.svg"/>
# <div class="mdCMN05Img">
# <img alt="冠緯與他的快樂夥伴 2" height="120" src="https://stickershop.line-scdn.net/stickershop/v1/product/18428342/LINEStorePC/main.png" width="120"/>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN02Li">
# <a class="FnRelatedStickerLink" data-index="40" href="/stickershop/product/19817163/zh-Hant?from=sticker" title="[Seseren] 羅德島的日常 ver.1">
# <div class="MdCMN05Item mdCMN05Sticker">
# <img alt="" class="MdIcoPremium_s" src="https://static.line-scdn.net/line_store/1814c5eeaa1/pc/img/common/img_charge_premium.svg"/>
# <div class="mdCMN05Img">
# <img alt="[Seseren] 羅德島的日常 ver.1" height="120" src="https://stickershop.line-scdn.net/stickershop/v1/product/19817163/LINEStorePC/main.png" width="120"/>
# <span class="MdIcoPlay_m" data-test="animation-sticker-icon">Animation only icon</span>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN02Li">
# <a class="FnRelatedStickerLink" data-index="41" href="/stickershop/product/19255881/zh-Hant?from=sticker" title="hololive sticker Vol.2">
# <div class="MdCMN05Item mdCMN05Sticker">
# <div class="mdCMN05Img">
# <img alt="hololive sticker Vol.2" height="120" src="https://stickershop.line-scdn.net/stickershop/v1/product/19255881/LINEStorePC/main.png" width="120"/>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN02Li">
# <a class="FnRelatedStickerLink" data-index="42" href="/stickershop/product/9728958/zh-Hant?from=sticker" title="Karameru Cry Cat stacker">
# <div class="MdCMN05Item mdCMN05Sticker">
# <img alt="" class="MdIcoPremium_s" src="https://static.line-scdn.net/line_store/1814c5eeaa1/pc/img/common/img_charge_premium.svg"/>
# <div class="mdCMN05Img">
# <img alt="Karameru Cry Cat stacker" height="120" src="https://stickershop.line-scdn.net/stickershop/v1/product/9728958/LINEStorePC/main.png" width="120"/>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN02Li">
# <a class="FnRelatedStickerLink" data-index="43" href="/stickershop/product/22432581/zh-Hant?from=sticker" title="竹筍日常-和尚系列(二代)">
# <div class="MdCMN05Item mdCMN05Sticker">
# <div class="mdCMN05Img">
# <img alt="竹筍日常-和尚系列(二代)" height="120" src="https://stickershop.line-scdn.net/stickershop/v1/product/22432581/LINEStorePC/main.png" width="120"/>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN02Li">
# <a class="FnRelatedStickerLink" data-index="44" href="/stickershop/product/22326741/zh-Hant?from=sticker" title='hololive sticker "Momosuzu Nene"'>
# <div class="MdCMN05Item mdCMN05Sticker">
# <div class="mdCMN05Img">
# <img alt='hololive sticker "Momosuzu Nene"' height="120" src="https://stickershop.line-scdn.net/stickershop/v1/product/22326741/LINEStorePC/main.png" width="120"/>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN02Li">
# <a class="FnRelatedStickerLink" data-index="45" href="/stickershop/product/19484075/zh-Hant?from=sticker" title='hololive sticker "Shirakami Fubuki" Vol2'>
# <div class="MdCMN05Item mdCMN05Sticker">
# <div class="mdCMN05Img">
# <img alt='hololive sticker "Shirakami Fubuki" Vol2' height="120" src="https://stickershop.line-scdn.net/stickershop/v1/product/19484075/LINEStorePC/main.png" width="120"/>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN02Li">
# <a class="FnRelatedStickerLink" data-index="46" href="/stickershop/product/19814476/zh-Hant?from=sticker" title="超負荷(Sam1268)">
# <div class="MdCMN05Item mdCMN05Sticker">
# <img alt="" class="MdIcoPremium_s" src="https://static.line-scdn.net/line_store/1814c5eeaa1/pc/img/common/img_charge_premium.svg"/>
# <div class="mdCMN05Img">
# <img alt="超負荷(Sam1268)" height="120" src="https://stickershop.line-scdn.net/stickershop/v1/product/19814476/LINEStorePC/main.png" width="120"/>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN02Li">
# <a class="FnRelatedStickerLink" data-index="47" href="/stickershop/product/21744917/zh-Hant?from=sticker" title="冠緯與他的快樂夥伴3">
# <div class="MdCMN05Item mdCMN05Sticker">
# <div class="mdCMN05Img">
# <img alt="冠緯與他的快樂夥伴3" height="120" src="https://stickershop.line-scdn.net/stickershop/v1/product/21744917/LINEStorePC/main.png" width="120"/>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN02Li">
# <a class="FnRelatedStickerLink" data-index="48" href="/stickershop/product/20121211/zh-Hant?from=sticker" title="懶貓子Rumi 天下第一可愛">
# <div class="MdCMN05Item mdCMN05Sticker">
# <div class="mdCMN05Img">
# <img alt="懶貓子Rumi 天下第一可愛" height="120" src="https://stickershop.line-scdn.net/stickershop/v1/product/20121211/LINEStorePC/main.png" width="120"/>
# <span class="MdIcoPlay_m" data-test="animation-sticker-icon">Animation only icon</span>
# </div>
# </div>
# </a>
# </li>
# <li class="mdCMN02Li">
# <a class="FnRelatedStickerLink" data-index="49" href="/stickershop/product/17532082/zh-Hant?from=sticker" title='hololive sticker "Murasaki Shion"'>
# <div class="MdCMN05Item mdCMN05Sticker">
# <div class="mdCMN05Img">
# <img alt='hololive sticker "Murasaki Shion"' height="120" src="https://stickershop.line-scdn.net/stickershop/v1/product/17532082/LINEStorePC/main.png" width="120"/>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <footer class="LyFoot" data-test="foot-menu" role="contentinfo">
# <!-- For TW -->
# <div class="lyFootInner">
# <h1 class="MdHide">LINE Taiwan Limited Link</h1>
# <div class="MdGFT02Link">
# <ul class="mdGFT02Ul" data-test="tw-foot-menu-ul">
# <li><a href="/terms/zh-Hant">服務條款</a>
# </li>
# <li><a href="https://terms.line.me/line_tw_privacy_policy?lang=zh-Hant" target="_blank">隱私權政策</a></li>
# <li><a href="https://terms.line.me/webstore_taiwan_mktpp?lang=zh-Hant">行銷資料提供政策</a></li>
# </ul>
# </div>
# <p class="MdGFT01Copy" data-test="company-name">
# <small><b>台灣連線股份有限公司　統一編號：24556886</b>
#           <b>©LINE Taiwan Limited.</b></small>
# </p>
# </div>
# <div class="MdGFT03Lang">
# <div class="mdGFT03NewSelect01" data-form=".FnLanguageSelectForm" data-widget="Select">
# <div class="mdGFT03Label"><span class="mdGFT03LabelTxt" data-test="set-language-txt"></span></div>
# <ul class="mdGFT03Ul MdHide" style="top: -202px">
# <li class="mdGFT03Li" data-action="/setLanguage/ja">
# <a class="mdGFT03Txt">日本語</a>
# </li>
# <li class="mdGFT03Li" data-action="/setLanguage/en">
# <a class="mdGFT03Txt">English</a>
# </li>
# <li class="mdGFT03Li" data-action="/setLanguage/zh-Hant" data-selected="true">
# <a class="mdGFT03Txt">中文(繁體)</a>
# </li>
# <li class="mdGFT03Li" data-action="/setLanguage/ko">
# <a class="mdGFT03Txt">한국어</a>
# </li>
# <li class="mdGFT03Li" data-action="/setLanguage/th">
# <a class="mdGFT03Txt">ภาษาไทย</a>
# </li>
# <li class="mdGFT03Li" data-action="/setLanguage/id">
# <a class="mdGFT03Txt">Bahasa Indonesia</a>
# </li>
# <li class="mdGFT03Li" data-action="/setLanguage/pt-BR">
# <a class="mdGFT03Txt">Português brasileiro</a>
# </li>
# </ul>
# <form action="/setLanguage/zh-Hant" class="FnLanguageSelectForm" method="POST"><input name="_csrf" type="hidden" value="1328bd32-cba1-43e7-a30e-3595301c60c7"/>
# <input class="FnUrl" name="url" type="hidden" value="/stickershop/product/19716012/zh-Hant"/>
# </form>
# </div>
# </div>
# </footer>
# <!-- friend item templates -->
# <script class="FnPresentFriendTemplate" type="text/template">
#     <tr>
#       <td class="mdLYR08TdImg">
#         <div class="mdLYR08Img"><span class="mdLYR08Shadow"></span><img src="{{imageUrl}}" /></div>
#       </td>
#       <td class="mdLYR08TdTxt">
#         <div class="mdLYR08Txt">{{name}}</div>
#       </td>
#       <td class="mdLYR08TdBtn"><a class="MdBtn05 FnFrindSelectBtn" href="javascript:;"><span
#         class="mdBtn05Inner"><span
#         class="mdBtn05Txt">選擇</span></span></a></td>
#     </tr>
#   </script>
# <!-- templates for radio buttons -->
# <script class="FnCallPlanRadioTemplate" type="text/template">
#     <li class="mdCMN17Li">
#       <label>
#         <div class="MdIcoRadio01 {{selectedClass}}">
#           <span class="mdIcoRadio01Ico"></span>
#           <input name="type" value="{{id}}" type="radio" data-price="{{displayPrice}}" data-product-id="{{id}}"
#                  data-item-type="{{type}}" />
#         </div>
#         <p class="mdCMN17LiTxt">{{name}}</p>
#       </label>
#     </li>
#   </script>
# </div>
# <div class="MdLYR01Box" data-widget="ModalWindow" data-widget-id="ModalWindowPresent" style="top: 50%; left: 50%; margin-left: -241px; margin-top: -305px; display: none;'">
# <div class="MdLYR02Body mdLYR02Present" data-friends-api="/api/present/friends/zh-Hant" data-package-id="123456" data-skip-template="true" data-submit-url="/stickershop/payment?packageId=19716012&amp;confirmedPrice=NT%2430" data-to-user-param="toUserMid" data-widget="PresentFriends" data-win-height="800" data-win-width="815">
# <a class="mdLYR02Close FnModalWindowClose" href="javascript:;"><span class="MdBtnClose01">關閉</span></a>
# <div class="MdLYR03Head">
# <h1 class="mdLYR03Ttl">選擇好友</h1>
# </div>
# <div data-tab-id="0" style="display: none;">
# <p class="mdLYR02Desc">請選擇要送禮的好友。</p>
# <div class="MdLYR07Search FnFriendsSearchWrap">
# <div class="mdLYR07SearchBox">
# <input class="FnFriendsSearchInput" id="" name="" placeholder="搜尋" type="text" value=""/><span class="MdIcoSearch02 FnFriendsSearchBtn"></span>
# </div>
# <div class="MdLYR08List">
# <p class="mdLYR08noR FnFriendsNoResults" style="display: none;">找不到符合條件的資料</p>
# <table class="mdLYR08Tbl FnFriendsTable"></table>
# </div>
# </div>
# </div>
# <div data-tab-id="1" style="display: none;">
# <p class="mdLYR02Desc">請選擇送禮通知的圖樣</p>
# <div class="MdLYR08List">
# <ul class="mdLYR08Ul" data-widget="RadioGroup" data-widget-id="presentFriendsRadioGroup">
# <li class="mdLYR08Li ExSelected">
# <label></label>
# <div class="MdIcoRadio02">
# <label><span class="mdIcoRadio02Ico"></span><input name="presentTemplateId" type="radio" value="0"/></label>
# </div>
# <label><span class="mdLYR08Img01">For You - Sticker Type 01</span></label>
# </li>
# <li class="mdLYR08Li">
# <label></label>
# <div class="MdIcoRadio02">
# <label><span class="mdIcoRadio02Ico"></span><input name="presentTemplateId" type="radio" value="1"/></label>
# </div>
# <label><span class="mdLYR08Img02">For You - Sticker Type 02</span></label>
# </li>
# <li class="mdLYR08Li">
# <label></label>
# <div class="MdIcoRadio02">
# <label><span class="mdIcoRadio02Ico"></span><input name="presentTemplateId" type="radio" value="2"/></label>
# </div>
# <label><span class="mdLYR08Img03">For You - Sticker Type 03</span></label>
# </li>
# <li class="mdLYR08Li">
# <label></label>
# <div class="MdIcoRadio02">
# <label><span class="mdIcoRadio02Ico"></span><input name="presentTemplateId" type="radio" value="3"/></label>
# </div>
# <label><span class="mdLYR08Img04">For You - Sticker Type 04</span></label>
# </li>
# </ul>
# <div class="mdLYR08Send">
# <p class="mdLYR08SendTxt">
#
#             </p>
# <div class="mdLYR08SendBtn">
# <a class="MdBtn01 mdBtn03 FnCancelBtn" href="javascript:;"><span class="mdBtn01Inner">
# <span class="mdBtn01Txt">取消</span></span></a>
# <a class="MdBtn01 mdBtn01 FnSubmitBtn" href="javascript:;">
# <span class="mdBtn01Inner">
# <span class="mdBtn01Txt">NT$30 購買</span>
# </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="MdLYR01Layer" data-widget="ModalWindow" data-widget-id="EnvironmentCaution" style="display: none;">
# <div class="mdLYR01Inner">
# <div class="mdLYR01Body">
# <div class="MdLYR22Caution">
# <h3 class="mdLYR22Ttl01">注意事項</h3>
# <p class="mdLYR22Txt01">適用於iOS、Android的LINE 9.12.0以上版本。</p>
# </div>
# </div>
# <div class="mdLYR01Foot">
# <button class="mdLYR01Close" data-event-name="closeModalWindow" data-event-target="EnvironmentCaution" data-widget="EventTrigger">關閉</button>
# </div>
# </div>
# </div>
# <!-- TODO: Add Condition for Movie block -->
# <div class="MdOverlay FnOverlay" style="display:none;"></div>
# <script type="text/javascript">
#   //<![CDATA[
#   //
#   var OPTIONS = {
#     config: {
#       debug: false,
#       pageType: "sticker_improve_detail",
#       staticUrl: "https:\/\/scdn.line-apps.com\/n\/"
#     },
#     // define messages only used in JS
#     messages: {}
#   };
#   OPTIONS.config.wishProduct = {
#     productType: "STICKER",
#     productId: "19716012"
#   };
#   //
#   //]]>
# </script>
# <script>/*<![CDATA[*/
#   (function (w, d, s, l, i) {
#     w[l] = w[l] || [];
#     w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#     var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#     j.async = true;
#     j.src = '//www.googletagmanager.com/gtm.js?id=' + i + dl;
#     f.parentNode.insertBefore(j, f);
#   })(window, document, 'script', 'dataLayer', 'GTM-TVHZDL');
#   /*]]>*/</script>
# <script>
#     OPTIONS.config.env = {
#       storeDomain: "store.line.me",
#       billingDomain: "store-bill.line.me",
#       lineScheme: "line"
#     };
#     OPTIONS.config.assetsUrl = "https:\/\/static.line-scdn.net\/line_store\/";
#     OPTIONS.config.tagNo = "18793c626e9";
#
#     OPTIONS.config.oa = {"friendShip":"UNSPECIFIED","searchId":"linestoretw"};
#
#     OPTIONS.config.userStateModel = {
#       isLoggedIn: false,
#       country: "TW",
#       language: "CHINESE_TRADITIONAL",
#       viewType: "PC",
#       isSmartphone: false,
#       isIOS: false,
#       hasCollapsedUserDisclaimer: false,
#       isPremiumUser: false
#     };
#
#     OPTIONS.config.mypage = {
#       hasNew: {
#         wishlist: false
#       }
#     };
#
#
#     OPTIONS.config.page = {
#       type: "END_PAGE",
#       status: {
#         isPremium: true
#       }
#     }
#
#
#     dataLayer.push({
#       'user': {
#         isLoggedIn: false,
#         viewType: "PC",
#         displayLanguage: "CHINESE_TRADITIONAL",
#         country: "TW",
#         currencyType: "TWD",
#         deviceModel: {
#           applicationType: "ANONYMOUS",
#           applicationVersion: "ANONYMOUS"
#         },
#       }
#     });
#
#     dataLayer.push({
#       salesInformation: {
#         priceTier: 1,
#         isCreators: true
#       },
#     });
#   </script>
# <script>
#     function redirectErrorPage(resourceName) {
#       if (!location.href.includes("load_script_failed")) {
#         var errorPageUrl = "\/error\/load_script_failed\/zh-Hant";
#         location.href = errorPageUrl + "?resourceName=" + resourceName;
#       }
#     }
#   </script>
# <script crossorigin="anonymous" onerror="redirectErrorPage('thrift')" src="https://static.line-scdn.net/line_store/16909542e95/thrift/thrift.js"></script>
# <script crossorigin="anonymous" onerror="redirectErrorPage('pcScript')" src="https://static.line-scdn.net/line_store/18793c626e9/pc/js/lc.line.store.pc.main.js"></script>
# <script>
#     window.popups = [{"id":"62d8e7a80f3e0f36827d8029","cookieName":"TW_STORE_FESTIVAL_POPUP_TEMPLATE","cookieExpirationDays":20,"endTime":"3000-01-01T00:00:00+09:00","templateType":"BASIC","confirmButtonUrl":"https:\/\/store.line.me\/notice\/20018429\/zh-Hant","paths":["\/","\/emojishop\/home","\/emojishop\/home\/.+","\/emojishop\/product\/.+","\/emojishop\/showcase\/.+","\/family\/manga","\/family\/uranai","\/game","\/game\/.+","\/home","\/stickershop\/home","\/stickershop\/home\/.+","\/stickershop\/product\/.+","\/stickershop\/showcase\/.+","\/themeshop\/home","\/themeshop\/home\/.+","\/themeshop\/product\/.+","\/themeshop\/showcase\/.+"],"displayOrder":500,"displayOnPremiumEndpageOnly":false,"titleXlt":"","title":"\u671F\u9593\u9650\u5B9A<br>LINE STORE \u8D85\u7D1A\u7279\u8CE3","descriptionXlt":"","description":"\u8CFC\u8CB7LINE STORE\u865B\u5BF6<br>\u8D85\u503C\u56DE\u994B\u591A\u66F4\u591A\uFF01","imageUrl":"https:\/\/obs.line-scdn.net\/0h8KpObgisZ2RNNnPbp_sYM2B0fAojUj5sb1l6VW1hbARjA3IydwQuCjsyPVRhA3JhclJ4B2syOwNmBigxeVgvCmtzOVVgAiFmeAA"}];
#   </script>
# <script>
#     window.experimentParams = {};
#   </script>
# <script onerror="redirectErrorPage('message')" src="/resource/messages.js/zh-Hant?lang=zh-Hant&amp;hash=59bf0fafb5173469f75d6b8a285e4235bc405358"></script>
# <script crossorigin="anonymous" onerror="redirectErrorPage('spaChunckScript')" src="https://static.line-scdn.net/line_store/edge/store/vendors~main.7b3f4501.min.js"></script>
# <script crossorigin="anonymous" onerror="redirectErrorPage('spaScript')" src="https://static.line-scdn.net/line_store/edge/store/main.08d56d9e.min.js"></script>
# </body>
# </html>

# %%
li_elements = soup.select("ul.mdCMN09Ul FnStickerList > mdCMN09Li FnStickerPreviewItem")

li_elements
for li in li_elements:
    strJson = li["data-preview"]
    
    obj = json.loads(strJson)
    
    listlineStickers.append(obj)
    
for obj in listlineStickers:
    os.system(f"curl {obj['staticUrl']} -o {folderPath}/{obj['id']}.png")
    print(f"貼圖ID: {obj['id']}, 下載連結: {obj['staticUrl']}")
# Out:
# 貼圖ID: 505815846, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815846/android/sticker.png
# 貼圖ID: 505815847, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815847/android/sticker.png
# 貼圖ID: 505815848, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815848/android/sticker.png
# 貼圖ID: 505815849, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815849/android/sticker.png
# 貼圖ID: 505815850, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815850/android/sticker.png
# 貼圖ID: 505815851, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815851/android/sticker.png
# 貼圖ID: 505815852, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815852/android/sticker.png
# 貼圖ID: 505815853, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815853/android/sticker.png
# 貼圖ID: 505815854, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815854/android/sticker.png
# 貼圖ID: 505815855, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815855/android/sticker.png
# 貼圖ID: 505815856, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815856/android/sticker.png
# 貼圖ID: 505815857, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815857/android/sticker.png
# 貼圖ID: 505815858, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815858/android/sticker.png
# 貼圖ID: 505815859, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815859/android/sticker.png
# 貼圖ID: 505815860, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815860/android/sticker.png
# 貼圖ID: 505815861, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815861/android/sticker.png
# 貼圖ID: 505815862, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815862/android/sticker.png
# 貼圖ID: 505815863, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815863/android/sticker.png
# 貼圖ID: 505815864, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815864/android/sticker.png
# 貼圖ID: 505815865, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815865/android/sticker.png
# 貼圖ID: 505815866, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815866/android/sticker.png
# 貼圖ID: 505815867, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815867/android/sticker.png
# 貼圖ID: 505815868, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815868/android/sticker.png
# 貼圖ID: 505815869, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815869/android/sticker.png
# 貼圖ID: 505815870, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815870/android/sticker.png
# 貼圖ID: 505815871, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815871/android/sticker.png
# 貼圖ID: 505815872, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815872/android/sticker.png
# 貼圖ID: 505815873, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815873/android/sticker.png
# 貼圖ID: 505815874, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815874/android/sticker.png
# 貼圖ID: 505815875, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815875/android/sticker.png
# 貼圖ID: 505815876, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815876/android/sticker.png
# 貼圖ID: 505815877, 下載連結: https://stickershop.line-scdn.net/stickershop/v1/sticker/505815877/android/sticker.png
